# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv("temp_data1.csv")
dataset.head()
# Out:
#    CPU Usage (%)  Memory Usage (%)  CPU Temperature (°C)
# 0            1.5              33.3                74.136
# 1            1.3              33.3                73.598
# 2            5.1              33.6                73.598
# 3           11.3              33.7                73.060
# 4            5.8              33.7                73.598

# %%
dataset.head()
dataset.dtypes
# Out:
# CPU Usage (%)           float64
# Memory Usage (%)        float64
# CPU Temperature (°C)    float64
# dtype: object

# %%
X = dataset.iloc[:,:2].values
X
# Out:
# array([[ 1.5, 33.3],
#        [ 1.3, 33.3],
#        [ 5.1, 33.6],
#        ...,
#        [ 2.5, 37.2],
#        [ 3. , 37.2],
#        [ 2.7, 37.2]])

# %%
Y = dataset.iloc[:,-1].values
Y
# Out:
# array([74.136, 73.598, 73.598, ..., 70.908, 71.446, 70.908])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
  
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(x_train, y_train)
# Out:
# SVR()

# %%
# Predicting a new result
y_pred = regressor.predict(x_test)
print(y_pred)

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Assuming you have y_test and y_pred
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# [70.75438191 70.72679962 70.93826402 ... 70.74183004 70.93217728
#  70.7952219 ]
# Mean Absolute Error: 0.722619042653895
# Mean Squared Error: 0.9327575426024436
# R-squared: 0.020916138806374773

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
print(mse)
# Out:
# 0.9327575426024436

# %%
import pickle
with open('svm_model3.pkl', 'wb') as f:
    pickle.dump((regressor), f)
